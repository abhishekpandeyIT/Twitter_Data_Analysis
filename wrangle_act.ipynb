# %% [markdown]
# # Wrangling and Analysis project
# > Authored by: **Abhishek Pandey** [LinkedIn](https://www.linkedin.com/in/abhishekpandeyit/) | [Twitter](https://twitter.com/PandeyJii_)

# %%
# Importing all required libraries
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import requests #For gathering data from website
import seaborn as sns
import tweepy
from datetime import datetime
from functools import reduce
# %matplotlib inline

# %% [markdown]
# # Gathering Data

# %%
df_tweet = pd.read_csv('F:/Github_repo/Wrangle_Analyse_Dataset/twitter-archive-enhanced-2.csv')

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv' 
response = requests.get(url)
with open(os.path.join('image_predictions.tsv'), mode = 'wb') as file:
    file.write(response.content)

# %%
images = pd.read_csv('F:/Github_repo/Wrangle_Analyse_Dataset/image_predictions.tsv', sep = '\t')

# %%
API_key = '0Z0ZK59KSOUWYr1X7qIRY9NHx'
API_secret_key = 'QxaSSKis3VdPIrIjdGhuGEa3DYO0i3LbyTuOwixWcA3cFScgqC'
access_token = '1257973204804612097-ttKDEV6otnE8W8aHzlsxNg8iaWL8Wm'
access_secret = '4bFOojkL6Q6eEEl0kTRVo6ZwJdGo9Y168CKAqy0e6yWor'

auth = tweepy.OAuthHandler(API_key, API_secret_key)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Using twitter Twitter API to collect the status data on tweets present in dataframe
tweet_ids = list(df_tweet['tweet_id'])

tweet_data = []
tweet_id_success = []
tweet_id_missing = []
for tweet_id in tweet_ids:
    try:
        data = api.get_status(tweet_id, 
                              tweet_mode='extended',
                              wait_on_rate_limit = True,
                              wait_on_rate_limit_notify = True)
        tweet_data.append(data)
        tweet_id_success.append(tweet_id)
    except:
        tweet_id_missing.append(tweet_id)
        print(tweet_id)
# Out:
# 81654872064
# 707411934438625280
# 707387676719185920
# 707377100785885184
# 707315916783140866
# 707297311098011648
# 707059547140169728
# 707038192327901184
# 707021089608753152
# 707014260413456384
# 706904523814649856
# 706901761596989440
# 706681918348251136
# 706644897839910912
# 706593038911545345
# 706538006853918722
# 706516534877929472
# 706346369204748288
# 706310011488698368
# 706291001778950144
# 706265994973601792
# 706169069255446529
# 706166467411222528
# 706153300320784384
# 705975130514706432
# 705970349788291072
# 705898680587526145
# 705786532653883392
# 705591895322394625
# 705475953783398401
# 705442520700944385
# 705428427625635840
# 705239209544720384
# 705223444686888960
# 705102439679201280
# 705066031337840642
# 704871453724954624
# 704859558691414016
# 704847917308362754
# 704819833553219584
# 704761120771465216
# 704499785726889984
# 704491224099647488
# 704480331685040129
# 704364645503647744
# 704347321748819968
# 704134088924532736
# 704113298707505153
# 704054845121142784
# 703774238772166656
# 703769065844768768
# 703631701117943808
# 703611486317502464
# 703425003149250560
# 703407252292673536
# 703382836347330562
# 703356393781329922
# 703268521220972544
# 703079050210877440
# 703041949650034688
# 702932127499816960
# 702899151802126337
# 702684942141153280
# 702671118226825216
# 702598099714314240
# 702539513671897089
# 702332542343577600
# 702321140488925184
# 702276748847800320
# 702217446468493312
# 701981390485725185
# 701952816642965504
# 701889187134500865
# 701805642395348998
# 701601587219795968
# 701570477911896070
# 701545186879471618
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['retweet_count', 'favorite_count'] not in index"

# %%
df_tweet.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1209  715696743237730304                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1203  716285507865542656                    NaN                  NaN
#
#                       timestamp  \
# 1209  2016-04-01 00:26:15 +0000
# 1165  2016-04-21 02:25:47 +0000
# 1203  2016-04-02 15:25:47 +0000
#
#                                                  source  \
# 1209  <a href="http://twitter.com/download/iphone" r...
# 1165  <a href="http://twitter.com/download/iphone" r...
# 1203  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1209  Meet Toby. He's a Lithuanian High-Steppin Stic...                  NaN
# 1165  Happy 4/20 from the squad! 13/10 for all https...                  NaN
# 1203  This is Stephanus. She stays woke. 12/10 https...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1209                       NaN                        NaN
# 1165                       NaN                        NaN
# 1203                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1209  https://twitter.com/dog_rates/status/715696743...                10
# 1165  https://twitter.com/dog_rates/status/722974582...                 4
# 1203  https://twitter.com/dog_rates/status/716285507...                12
#
#       rating_denominator       name doggo floofer pupper puppo
# 1209                  10       Toby  None    None   None  None
# 1165                  20       None  None    None   None  None
# 1203                  10  Stephanus  None    None   None  None

# %%
df_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
df_tweet['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
df_tweet['text'].value_counts()
# Out:
# Another magnificent photo. 12/10 https://t.co/X5w387K5jr                                                                                       1
# RT @twitter: @dog_rates Awesome Tweet! 12/10. Would Retweet. #LoveTwitter https://t.co/j6FQGhxYuN                                              1
# Here we have a mixed Asiago from the Galápagos Islands. Only one ear working. Big fan of marijuana carpet. 8/10 https://t.co/tltQ5w9aUO        1
# This is Flávio. He's a Macedonian Poppycock. 97% floof. Jubilant af. 11/10 personally I'd pet the hell out of https://t.co/BUyX7isHRg          1
# This is Izzy. She's showing off the dance moves she's been working on. 11/10 I guess hard work pays off https://t.co/4JS92YAxTi                1
#                                                                                                                                               ..
# This is Monster. Not an actual monster tho. He's showing you his tongue. Very impressive Monster. 12/10 would snug https://t.co/RhaPExuxJL     1
# Say hello to Lily. She's not injured or anything. Just wants everyone to hear her. 9/10 clever af https://t.co/3xqGVH0Dhw                      1
# Breathtaking pupper here. Should be on the cover of Dogue. Top-notch tongue. Appears considerably fluffy. 12/10 https://t.co/Eeh3yfdglS        1
# Right after you graduate vs when you remember you're on your own now and can barely work a washing machine ...10/10 https://t.co/O1TLuYjsNS    1
# This is Pippin. He is terrified of his new little yellow giraffe. 11/10 https://t.co/ZICNl6tIr5                                                1
# Name: text, Length: 2356, dtype: int64

# %%
df_tweet['retweeted_status_id'].value_counts()
# Out:
# 7.757333e+17    1
# 7.507196e+17    1
# 6.742918e+17    1
# 6.833919e+17    1
# 8.269587e+17    1
#                ..
# 7.848260e+17    1
# 7.806013e+17    1
# 8.305833e+17    1
# 7.047611e+17    1
# 7.331095e+17    1
# Name: retweeted_status_id, Length: 181, dtype: int64

# %%
df_tweet['retweeted_status_user_id'].value_counts()
# Out:
# 4.196984e+09    156
# 4.296832e+09      2
# 5.870972e+07      1
# 6.669901e+07      1
# 4.119842e+07      1
# 7.475543e+17      1
# 7.832140e+05      1
# 7.266347e+08      1
# 4.871977e+08      1
# 5.970642e+08      1
# 4.466750e+07      1
# 1.228326e+09      1
# 7.992370e+07      1
# 2.488557e+07      1
# 7.874618e+17      1
# 3.638908e+08      1
# 5.128045e+08      1
# 8.117408e+08      1
# 1.732729e+09      1
# 1.960740e+07      1
# 1.547674e+08      1
# 3.410211e+08      1
# 7.124572e+17      1
# 2.804798e+08      1
# 1.950368e+08      1
# Name: retweeted_status_user_id, dtype: int64

# %%
df_tweet['retweeted_status_timestamp'].value_counts()
# Out:
# 2017-02-28 18:43:57 +0000    1
# 2016-10-26 22:31:36 +0000    1
# 2015-12-12 02:23:01 +0000    1
# 2016-07-30 17:56:51 +0000    1
# 2016-01-25 00:26:41 +0000    1
#                             ..
# 2016-01-08 05:00:14 +0000    1
# 2017-05-18 01:17:25 +0000    1
# 2017-02-24 23:04:14 +0000    1
# 2016-08-11 20:40:41 +0000    1
# 2016-11-06 01:33:58 +0000    1
# Name: retweeted_status_timestamp, Length: 181, dtype: int64

# %%
df_tweet['expanded_urls'].value_counts()
# Out:
# https://twitter.com/dog_rates/status/783839966405230592/photo/1,https://twitter.com/dog_rates/status/783839966405230592/photo/1,https://twitter.com/dog_rates/status/783839966405230592/photo/1                                                                    2
# https://www.gofundme.com/3hgsuu0,https://twitter.com/dog_rates/status/840632337062862849/photo/1                                                                                                                                                                   2
# https://www.loveyourmelon.com/pages/ourstory,https://twitter.com/dog_rates/status/820314633777061888/photo/1,https://twitter.com/dog_rates/status/820314633777061888/photo/1,https://twitter.com/dog_rates/status/820314633777061888/photo/1                       2
# https://twitter.com/dog_rates/status/791406955684368384/photo/1,https://twitter.com/dog_rates/status/791406955684368384/photo/1,https://twitter.com/dog_rates/status/791406955684368384/photo/1,https://twitter.com/dog_rates/status/791406955684368384/photo/1    2
# https://twitter.com/dog_rates/status/669000397445533696/photo/1                                                                                                                                                                                                    2
#                                                                                                                                                                                                                                                                   ..
# https://vine.co/v/iDrOvVqq0A6                                                                                                                                                                                                                                      1
# https://twitter.com/dog_rates/status/707059547140169728/photo/1,https://twitter.com/dog_rates/status/707059547140169728/photo/1                                                                                                                                    1
# https://twitter.com/dog_rates/status/667090893657276420/photo/1                                                                                                                                                                                                    1
# https://twitter.com/dog_rates/status/761292947749015552/photo/1                                                                                                                                                                                                    1
# https://twitter.com/dog_rates/status/679062614270468097/photo/1,https://twitter.com/dog_rates/status/679062614270468097/photo/1                                                                                                                                    1
# Name: expanded_urls, Length: 2218, dtype: int64

# %%
df_tweet['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
df_tweet['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
df_tweet['name'].value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
#           ...
# Pancake      1
# light        1
# Harlso       1
# Horace       1
# Kial         1
# Name: name, Length: 957, dtype: int64

# %%
df_tweet['doggo'].value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
df_tweet['floofer'].value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df_tweet['pupper'].value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
df_tweet['puppo'].value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
df_tweet.loc[twitter1['name'].str.isupper()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9090a676260a> in <module>
# ----> 1 df_tweet.loc[twitter1['name'].str.isupper()]
#
# NameError: name 'twitter1' is not defined

# %%
df_new.sample(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-730c54f48a20> in <module>
# ----> 1 df_new.sample(10)
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5059             )
#    5060
# -> 5061         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5062         return self.take(locs, axis=axis)
#    5063
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 0 entries
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  0 non-null      float64
# dtypes: float64(1)
# memory usage: 0.0 bytes

# %%
df_new['tweet_id'].value_counts()
# Out:
# Series([], Name: tweet_id, dtype: int64)

# %%
df_new['favorite_count'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'favorite_count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-3e697cc1e0e2> in <module>
# ----> 1 df_new['favorite_count'].value_counts()
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'favorite_count'

# %%
df_new['retweet_count'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'retweet_count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-d61b33f94003> in <module>
# ----> 1 df_new['retweet_count'].value_counts()
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'retweet_count'

# %%
images.sample(2)
# Out:
#                 tweet_id                                          jpg_url  \
# 874   698178924120031232  https://pbs.twimg.com/media/CbBuBhbWwAEGH29.jpg
# 1346  759197388317847553  https://pbs.twimg.com/media/Cok1_sjXgAU3xpp.jpg
#
#       img_num                        p1   p1_conf  p1_dog                p2  \
# 874         1  Chesapeake_Bay_retriever  0.351868    True          malinois
# 1346        1                    kuvasz  0.511341    True  golden_retriever
#
#        p2_conf  p2_dog                  p3   p3_conf  p3_dog
# 874   0.207753    True  Labrador_retriever  0.154606    True
# 1346  0.076899    True          white_wolf  0.063269   False

# %%
images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
images['tweet_id'].value_counts()
# Out:
# 685532292383666176    1
# 826598365270007810    1
# 692158366030913536    1
# 714606013974974464    1
# 715696743237730304    1
#                      ..
# 816829038950027264    1
# 847971574464610304    1
# 713175907180089344    1
# 670338931251150849    1
# 700151421916807169    1
# Name: tweet_id, Length: 2075, dtype: int64

# %%
images['jpg_url'].value_counts()
# Out:
# https://pbs.twimg.com/media/Cveg1-NXgAASaaT.jpg    2
# https://pbs.twimg.com/media/CtzKC7zXEAALfSo.jpg    2
# https://pbs.twimg.com/media/CsGnz64WYAEIDHJ.jpg    2
# https://pbs.twimg.com/media/Cx5R8wPVEAALa9r.jpg    2
# https://pbs.twimg.com/media/CcG07BYW0AErrC9.jpg    2
#                                                   ..
# https://pbs.twimg.com/media/CXMBhXfWEAA4mMI.jpg    1
# https://pbs.twimg.com/media/CUHkkJpXIAA2w3n.jpg    1
# https://pbs.twimg.com/media/CUI6uuaW4AAvCIs.jpg    1
# https://pbs.twimg.com/media/C0dSk98WEAALyya.jpg    1
# https://pbs.twimg.com/media/Crdhh_1XEAAHKHi.jpg    1
# Name: jpg_url, Length: 2009, dtype: int64

# %%
images['img_num'].value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
images['p1'].value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# dhole                   1
# nail                    1
# walking_stick           1
# tricycle                1
# rain_barrel             1
# Name: p1, Length: 378, dtype: int64

# %%
images['p1_conf'].value_counts()
# Out:
# 0.366248    2
# 0.713293    2
# 0.375098    2
# 0.636169    2
# 0.611525    2
#            ..
# 0.713102    1
# 0.765266    1
# 0.491022    1
# 0.905334    1
# 1.000000    1
# Name: p1_conf, Length: 2006, dtype: int64

# %%
images['p1_dog'].value_counts()
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64

# %%
images['p2'].value_counts()
# Out:
# Labrador_retriever    104
# golden_retriever       92
# Cardigan               73
# Chihuahua              44
# Pomeranian             42
#                      ...
# sweatshirt              1
# mashed_potato           1
# patio                   1
# breakwater              1
# Kerry_blue_terrier      1
# Name: p2, Length: 405, dtype: int64

# %%
images['p2_conf'].value_counts()
# Out:
# 0.069362    3
# 0.027907    2
# 0.193654    2
# 0.271929    2
# 0.003143    2
#            ..
# 0.138331    1
# 0.254884    1
# 0.090644    1
# 0.219323    1
# 0.016301    1
# Name: p2_conf, Length: 2004, dtype: int64

# %%
images['p2_dog'].value_counts()
# Out:
# True     1553
# False     522
# Name: p2_dog, dtype: int64

# %%
images['p3'].value_counts()
# Out:
# Labrador_retriever    79
# Chihuahua             58
# golden_retriever      48
# Eskimo_dog            38
# kelpie                35
#                       ..
# parachute              1
# French_horn            1
# theater_curtain        1
# eel                    1
# Kerry_blue_terrier     1
# Name: p3, Length: 408, dtype: int64

# %%
images['p3_conf'].value_counts()
# Out:
# 0.094759    2
# 0.035711    2
# 0.000428    2
# 0.044660    2
# 0.162084    2
#            ..
# 0.024007    1
# 0.132820    1
# 0.002099    1
# 0.083643    1
# 0.033835    1
# Name: p3_conf, Length: 2006, dtype: int64

# %%
images['p3_dog'].value_counts()
# Out:
# True     1499
# False     576
# Name: p3_dog, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# Make copies of the dataframes for cleaning

twitter1_clean = df_tweet.copy()
twitter2_clean = df_new.copy()
images_clean = images.copy()

# %% [markdown]
# Twitter2 and images data must combined with twitter1 data as they contain information about the same tweet, therefore merging these 3 dataframes

# %%
'''
Merging twitter1, twitter2, and images dataframes with 'tweet_id''''
dfs = [twitter1_clean, twitter2_clean, images_clean]
twitter = reduce(lambda left,right: pd.merge(left,right,on='tweet_id'), dfs)
# Out:
#   File "<ipython-input-45-83242d0ba60c>", line 2
#     Merging twitter1, twitter2, and images dataframes with 'tweet_id''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
twitter.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-244d8032b82d> in <module>
# ----> 1 twitter.head(2)
#
# NameError: name 'twitter' is not defined

# %%
twitter.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-87c6fddf256a> in <module>
# ----> 1 twitter.info()
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### Find another issue i.e. 1 variable (dog stage) in 4 different columns (doggo, floofer, pupper, and puppo), to solve this issue extracting the dog stages from the 'text' column into the new 'dog_stage' column using regular expression then droping the 'doggo', 'floofer', 'pupper', and 'puppo' columns.  This also takes care of the quality issue of "name has values that are the string "None" instead of NaN".

# %%
twitter['dog_stage'] = twitter['text'].str.extract('(doggo|floofer|pupper|puppo)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-3a86075a6b9d> in <module>
# ----> 1 twitter['dog_stage'] = twitter['text'].str.extract('(doggo|floofer|pupper|puppo)')
#
# NameError: name 'twitter' is not defined

# %%
twitter[['dog_stage','doggo', 'floofer', 'pupper', 'puppo']].head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2a9cb2ad27ad> in <module>
# ----> 1 twitter[['dog_stage','doggo', 'floofer', 'pupper', 'puppo']].head(15)
#
# NameError: name 'twitter' is not defined

# %%
twitter = twitter.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1) #Dropping the columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-cd60f29e6f88> in <module>
# ----> 1 twitter = twitter.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1) #Dropping the columns
#
# NameError: name 'twitter' is not defined

# %%
twitter.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-87c6fddf256a> in <module>
# ----> 1 twitter.info()
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### Next issue needs to be readdressed is that data contains retweets. To solve this issue Rows where 'retweeted_status_id' is a NaN will be kept (ie. if it has a value it will be removed), then the 'retweeted_status_id', 'retweeted_status_user_id' and 'retweeted_status_timestamp' columns will be removed.

# %%
twitter = twitter[np.isnan(twitter.retweeted_status_id)]

print(twitter.info())

twitter = twitter.drop(['retweeted_status_id', 
                        'retweeted_status_user_id', 
                        'retweeted_status_timestamp'], 
                       axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-733a755a020d> in <module>
# ----> 1 twitter = twitter[np.isnan(twitter.retweeted_status_id)]
#       2
#       3 print(twitter.info())
#       4
#       5 twitter = twitter.drop(['retweeted_status_id',
#
# NameError: name 'twitter' is not defined

# %%
twitter.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-87c6fddf256a> in <module>
# ----> 1 twitter.info()
#
# NameError: name 'twitter' is not defined

# %%
# casting tweet_id into string type
twitter['tweet_id'] = twitter['tweet_id'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3f9112673d3d> in <module>
#       1 # casting tweet_id into string type
# ----> 2 twitter['tweet_id'] = twitter['tweet_id'].astype(str)
#
# NameError: name 'twitter' is not defined

# %%
twitter.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-87c6fddf256a> in <module>
# ----> 1 twitter.info()
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### 'timestamp' and 'retweeted_status_timestamp' are currently of type 'object' therefore Converting 'timestamp' to a datetime object ('retweeted_status_timestamp' was deleted)

# %%
twitter['timestamp'] = twitter['timestamp'].str.slice(start=0, stop=-6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-bd12d12a4c7d> in <module>
# ----> 1 twitter['timestamp'] = twitter['timestamp'].str.slice(start=0, stop=-6)
#
# NameError: name 'twitter' is not defined

# %%
twitter['timestamp'] = pd.to_datetime(twitter['timestamp'], format = "%Y-%m-%d %H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-150dc79e1a9a> in <module>
# ----> 1 twitter['timestamp'] = pd.to_datetime(twitter['timestamp'], format = "%Y-%m-%d %H:%M:%S")
#
# NameError: name 'twitter' is not defined

# %%
twitter.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-87c6fddf256a> in <module>
# ----> 1 twitter.info()
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### Here I found several issues
# - 1. name has values that are the string "None" instead of NaN
# - 2. Looking programmatically, some names are inaccurate such as "a", "an", "the", "very", "by", etc.  Looking visually in Excel, I was able to find more names that are inaccurate including "actually", "quite", "unacceptable", "mad", "not" and "old.  It seems like the method used to extract the names was using the word the followed "This is..." and "Here is..." which leads to some inaccuracies.
# - 3. I also found an instand of a name being "O" instead of "O'Malley"

# %%
'''Replacing all inaccurate names with NaNs, and the "O" with "O'Malley".Find all names that start with a lowercase letter'''
lowercase_names = []
for row in twitter['name']:
    if row[0].islower() and row not in lowercase_names:
        lowercase_names.append(row)
print(lowercase_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-3c9c5570080f> in <module>
#       1 '''Replacing all inaccurate names with NaNs, and the "O" with "O'Malley".Find all names that start with a lowercase letter'''
#       2 lowercase_names = []
# ----> 3 for row in twitter['name']:
#       4     if row[0].islower() and row not in lowercase_names:
#       5         lowercase_names.append(row)
#
# NameError: name 'twitter' is not defined

# %%
twitter['name'].replace(lowercase_names, 
                        np.nan,
                       inplace = True)

twitter['name'].replace('None', 
                        np.nan,
                       inplace = True)

twitter['name'].replace('O', 
                        "O'Malley",
                       inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-1c7897477265> in <module>
# ----> 1 twitter['name'].replace(lowercase_names,
#       2                         np.nan,
#       3                        inplace = True)
#       4
#       5 twitter['name'].replace('None',
#
# NameError: name 'twitter' is not defined

# %%
twitter['name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-ca1c53360e87> in <module>
# ----> 1 twitter['name'].value_counts()
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### Find 1 more issue i.e.  Some ratings with decimals such as 13.5/10, 9.5/10 have been incorrectly exported as 5/10 (in addition to other numbers with decimals such as 11.26 and 11.27). therefore Finding all instances of ratings that contained decimals and replace the numerator values with the correct values.

# %%
'''
Obtain all text, indices, and ratings for tweets that contain a decimal in the numerator of rating
'''
ratings_with_decimals_text = []
ratings_with_decimals_index = []
ratings_with_decimals = []

for i, text in twitter['text'].iteritems():
    if bool(re.search('\d+\.\d+\/\d+', text)):
        ratings_with_decimals_text.append(text)
        ratings_with_decimals_index.append(i)
        ratings_with_decimals.append(re.search('\d+\.\d+', text).group())

# Print the text to confirm presence of ratings with decimals        
ratings_with_decimals_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-d1cf14b5c002> in <module>
#       6 ratings_with_decimals = []
#       7
# ----> 8 for i, text in twitter['text'].iteritems():
#       9     if bool(re.search('\d+\.\d+\/\d+', text)):
#      10         ratings_with_decimals_text.append(text)
#
# NameError: name 'twitter' is not defined

# %%
# Printing indexs of text with decimal ratings
ratings_with_decimals_index
# Out:
# []

# %%
twitter.loc[ratings_with_decimals_index[0],'rating_numerator'] = float(ratings_with_decimals[0])
twitter.loc[ratings_with_decimals_index[1],'rating_numerator'] = float(ratings_with_decimals[1])
twitter.loc[ratings_with_decimals_index[2],'rating_numerator'] = float(ratings_with_decimals[2])
twitter.loc[ratings_with_decimals_index[3],'rating_numerator'] = float(ratings_with_decimals[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-23fe41fd8271> in <module>
# ----> 1 twitter.loc[ratings_with_decimals_index[0],'rating_numerator'] = float(ratings_with_decimals[0])
#       2 twitter.loc[ratings_with_decimals_index[1],'rating_numerator'] = float(ratings_with_decimals[1])
#       3 twitter.loc[ratings_with_decimals_index[2],'rating_numerator'] = float(ratings_with_decimals[2])
#       4 twitter.loc[ratings_with_decimals_index[3],'rating_numerator'] = float(ratings_with_decimals[3])
#
# IndexError: list index out of range

# %%
twitter.loc[40] # Check contents of row with index 40 to ensure the rating is corrected
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-5852463bca6b> in <module>
# ----> 1 twitter.loc[40] # Check contents of row with index 40 to ensure the rating is corrected
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### For future analysis it could be confusing to interpret unstandardized ratings.  It is their gimmick to give dogs a rating of 100% but not all are above 100% so it could be interesting to see what percentage are below or above 100 and how this has been changed overtime by calculating a single value for rating, to solve this issue calulating the value of the numerator divided by the denominator and save this in a new column called 'rating'.

# %%
twitter['rating'] = twitter['rating_numerator'] / twitter['rating_denominator']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-95339b34a8b1> in <module>
# ----> 1 twitter['rating'] = twitter['rating_numerator'] / twitter['rating_denominator']
#
# NameError: name 'twitter' is not defined

# %%
# Checking the presence of column and calculation
twitter.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-50bf9909890e> in <module>
#       1 # Checking the presence of column and calculation
# ----> 2 twitter.head(1)
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# There are many columns in this dataframe making it hard to read, and some will not be needed for analysis.  In addition some of the text in the table output is cut off.
# <br>**Solution**: Drop undesired columns and change table display settings.

# %%
# Viewing all columns name
twitter.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-aa52fe36ef77> in <module>
#       1 # Viewing all columns name
# ----> 2 twitter.columns
#
# NameError: name 'twitter' is not defined

# %%
twitter.rename(columns={'rating_numerator': 'numerator', 
                        'rating_denominator': 'denominator'}, inplace=True) #Shortning column names

'''
Droping unwanted columns
'''
twitter.drop(['in_reply_to_status_id', 
              'in_reply_to_user_id',
              'source',
              'img_num'], axis=1, inplace=True)

pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-2edb3f8be4c1> in <module>
# ----> 1 twitter.rename(columns={'rating_numerator': 'numerator',
#       2                         'rating_denominator': 'denominator'}, inplace=True) #Shortning column names
#       3
#       4 '''
#       5 Droping unwanted columns
#
# NameError: name 'twitter' is not defined

# %%
#Confirming changes
twitter.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-4438a9f3533c> in <module>
#       1 #Confirming changes
# ----> 2 twitter.head(1)
#
# NameError: name 'twitter' is not defined

# %%
# Storing dataframe to a new file.
twitter.to_csv('twitter_archive_master.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-142d9897d8a3> in <module>
#       1 # Storing dataframe to a new file.
# ----> 2 twitter.to_csv('twitter_archive_master.csv')
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ## Visualization

# %%
sns.lmplot(x="retweet_count", 
           y="favorite_count", 
           data=twitter,
           size = 5,
           aspect=1.3,
           scatter_kws={'alpha':1/5})
plt.title('Favorite Tweets vs. Retweet Count')
plt.xlabel('Retweet Count')
plt.ylabel('Favorite Count');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-47df063d1d33> in <module>
#       1 sns.lmplot(x="retweet_count",
#       2            y="favorite_count",
# ----> 3            data=twitter,
#       4            size = 5,
#       5            aspect=1.3,
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# Graphs shows a strong positive correlation between Favorite and retweet counts.

# %%
twitter.groupby('timestamp')['rating'].mean().plot(kind='line')
plt.title('Rating over Time')
plt.xlabel('Time')
plt.ylabel('Standardized Rating')
plt.show;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-004b811b51b2> in <module>
# ----> 1 twitter.groupby('timestamp')['rating'].mean().plot(kind='line')
#       2 plt.title('Rating over Time')
#       3 plt.xlabel('Time')
#       4 plt.ylabel('Standardized Rating')
#       5 plt.show;
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# ### There are 3 outliers with a rating over 2

# %%
twitter.loc[twitter['rating'] > 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-7b9303d9d25b> in <module>
# ----> 1 twitter.loc[twitter['rating'] > 2]
#
# NameError: name 'twitter' is not defined

# %% [markdown]
# An inaccurate finding (rating of 24/7) found here at the first instance. I decided to leave this unfixed as we can easily ignore this. The other 2 tweets are accurate ratings i.e jokes. Thus I am interestedto find that if the tweets with a standardized rating below than 1, decrease over time or not, therefore I'm limiting the y axis from 0 to 2.

# %%
"""
Plotting standardized ratings over time with ylim of 0-2 to find accurate answers
"""

twitter.groupby('timestamp')['rating'].mean().plot(kind='line')
plt.ylim(0, 2)
plt.title('Rating over Time')
plt.xlabel('Time')
plt.ylabel('Standardized Rating')
plt.show;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-ca8a5be25eb2> in <module>
#       3 """
#       4
# ----> 5 twitter.groupby('timestamp')['rating'].mean().plot(kind='line')
#       6 plt.ylim(0, 2)
#       7 plt.title('Rating over Time')
#
# NameError: name 'twitter' is not defined
